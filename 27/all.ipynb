# %%
def f(xm, ym):
    xs = 0
    ys = 0
    best = float('inf')
    for q in range(len(xm)):
        s = 0
        for w in range(len(xm)):
            s+= (abs(xm[w]-xm[q]) + abs(ym[w]-xm[q]))
        if s < best:
            best = s
            xs = xm[q]
            ys = ym[q]
    return xs, ys

# %%
def centroid(x, y):
    best_x = 0
    best_y = 0
    best_sum = float('inf')
    
    for i in range(len(x)):
        s = 0
        for j in range(len(x)):
            s += math.sqrt((x[i] - x[j])**2 + (y[i] - y[j])**2)
        
        if s < best_sum:
            best_sum = s
            best_x = x[i]
            best_y = y[i]
    
    return best_x, best_y
