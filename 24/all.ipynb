# %%
from math import e


with open('24_1.txt') as f:
    s = f.readline()

cnt = 0
i = 0

while i < len(s) - 5:
    if s[i] not in '0123456789ABCDEF':
        i +=1
    else:
        if s[i+1] not in '0123456789ABCDEF':
            i +=1
        else:
            if s[i+2] not in '0123456789ABCDEF':
                i +=1
            else:
                if s[i+3] not in '0123456789ABCDEF':
                    i +=1
                else:
                    if s[i+4] not in '0123456789ABCDEF':
                        i +=1
                    else:
                        if s[i+5] not in '0123456789ABCDEF':
                            i +=1
                        else:
                            cnt += 1
                            i += 6
cnt
# Out:
# 1134636

# %%
with open('24_2.txt') as f:
    s = f.readline()
cnt =0
sq = []
i = 0
c =0
while i < len(s) - 1:
    if s[i] in 'AE' and s[i+1] in 'BCDF':
        cnt += 1
        i += 1
        c +=1
    if c <= 130:
        i += 1
        cnt += 1
    else:
        sq.append(cnt)
        cnt = 0
        c = 0
        i += 1

max(sq)
# Out:
# 618

# %% [markdown]
# Текстовый файл  (24_3) состоит не более чем из 106 символов X, Y и Z. Определите максимальное количество идущих подряд символов, среди которых каждые два соседних различны.
#
# Для выполнения этого задания следует написать программу. Ниже приведён файл, который необходимо обработать с помощью данного алгоритма.

# %%
with open('24_3.txt') as f:
    s = f.readline()
cnt = 1
lens = []
for i in range(len(s) -1):
    if s[i] != s[i + 1]:
        cnt += 1
    else:
        lens.append(cnt)
        cnt = 1

max(lens)
# Out:
# 35

# %% [markdown]
# Текстовый файл 24_4 состоит не более чем из 106 символов X, Y и Z. Определите максимальную длину цепочки вида XYZXYZXYZ... (составленной из фрагментов XYZ, последний фрагмент может быть неполным).
#
# Для выполнения этого задания следует написать программу. Ниже приведён файл, который необходимо обработать с помощью данного алгоритма.

# %%
with open('24_4.txt') as f:
    s =f.readline()

i = 0
lens = []
cnt = 0
while i < len(s) - 2:
    if s[i] == 'X':
        if s[i+1]=='Y':
            if s[i+2] == 'Z':
                i += 3
                cnt += 3
            else:
                i += 2
                cnt += 2
                lens.append(cnt)
                cnt = 0
        else:
            i +=1
            cnt += 1
            lens.append(cnt)
            cnt = 0
    else:
        i += 1
        cnt = 0
        lens.append(cnt)

max(lens)
# Out:
# 13

# %% [markdown]
# Текстовый файл (24_5) состоит не более чем из 106 символов L, D и R. Определите максимальную длину цепочки вида LDRLDRLDR... (составленной из фрагментов LDR, последний фрагмент может быть неполным).
#
# Для выполнения этого задания следует написать программу. Ниже приведён файл, который необходимо обработать с помощью данного алгоритма.

# %%
with open('24_5.txt') as f:
    s =f.readline()

i = 0
lens = []
cnt = 0
while i < len(s) - 2:
    if s[i] == 'L':
        if s[i+1]=='D':
            if s[i+2] == 'R':
                i += 3
                cnt += 3
            else:
                i += 2
                cnt += 2
                lens.append(cnt)
                cnt = 0
        else:
            i +=1
            cnt += 1
            lens.append(cnt)
            cnt = 0
    else:
        i += 1
        lens.append(cnt)
        cnt = 0

max(lens)
# Out:
# 15

# %% [markdown]
# Текстовый файл 24_6 содержит только заглавные буквы латинского алфавита (ABC…Z). Определите символ, который чаще всего встречается в файле сразу после буквы A.
#
# Например, в тексте ABCAABADDD после буквы A два раза стоит B, по одному разу  — A и D. Для этого текста ответом будет B.
#
# Для выполнения этого задания следует написать программу. Ниже приведён файл, который необходимо обработать с помощью данного алгоритма.

# %%
with open('24_6.txt') as f:
    s = f.readline()

d = dict()
for ch in 'QWERTYUIOPASDFGHJKLZXCVBNM':
    d[ch] = 0

for i in range(len(s) - 1):
    if s[i] == 'A':
        d[s[i+1]] += 1

d
# Out:
# {'Q': 1517,
#  'W': 1450,
#  'E': 1478,
#  'R': 1439,
#  'T': 1457,
#  'Y': 1450,
#  'U': 1457,
#  'I': 1435,
#  'O': 1459,
#  'P': 1509,
#  'A': 1459,
#  'S': 1521,
#  'D': 1487,
#  'F': 1526,
#  'G': 1555,
#  'H': 1467,
#  'J': 1423,
#  'K': 1511,
#  'L': 1416,
#  'Z': 1513,
#  'X': 1480,
#  'C': 1452,
#  'V': 1502,
#  'B': 1505,
#  'N': 1504,
#  'M': 1436}

# %% [markdown]
# Текстовый файл 24_7 содержит только заглавные буквы латинского алфавита (ABC…Z). Определите символ, который чаще всего встречается в файле между двумя одинаковыми символами.
#
# Например, в тексте CBCABABACCC есть комбинации CBC, ABA (два раза), BAB и CCC. Чаще всего  — 3 раза  — между двумя одинаковыми символами стоит B, в ответе для этого случая надо написать B.
#
# Для выполнения этого задания следует написать программу. Ниже приведён файл, который необходимо обработать с помощью данного алгоритма.

# %%
with open('24_6.txt') as f:
    s = f.readline()

d = dict()
for ch in 'QWERTYUIOPASDFGHJKLZXCVBNM':
    d[ch] = 0

for i in range(len(s)-2):
    if s[i] == s[i +2]:
        d[s[i+1]] +=1

d
# Out:
# {'Q': 1468,
#  'W': 1490,
#  'E': 1400,
#  'R': 1461,
#  'T': 1410,
#  'Y': 1441,
#  'U': 1445,
#  'I': 1446,
#  'O': 1507,
#  'P': 1502,
#  'A': 1509,
#  'S': 1501,
#  'D': 1517,
#  'F': 1446,
#  'G': 1502,
#  'H': 1479,
#  'J': 1461,
#  'K': 1443,
#  'L': 1459,
#  'Z': 1447,
#  'X': 1490,
#  'C': 1400,
#  'V': 1505,
#  'B': 1423,
#  'N': 1439,
#  'M': 1481}

# %% [markdown]
# Текстовый файл 24_8 содержит строки различной длины. Общий объём файла не превышает 1 Мбайт. Строки содержат только заглавные буквы латинского алфавита (ABC…Z).
#
# В строках, содержащих менее 25 букв A, нужно определить и вывести максимальное расстояние между одинаковыми буквами в одной строке.
#
# Пример. Исходный файл:
#
# GIGA
#
# GABLAB
#
# NOTEBOOK
#
# AGAAA
#
# В этом примере во всех строках меньше 25 букв A. Самое большое расстояние между одинаковыми буквами  — в третьей строке между буквами O, расположенными в строке на 2-⁠й и 7-⁠й позициях. В ответе для данного примера нужно вывести число 5.
#
# Для выполнения этого задания следует написать программу. Ниже приведён файл, который необходимо обработать с помощью данного алгоритма.

# %%
with open('24_8.txt') as f:
    s = [x for x in f.readlines()]
lens = []
for i in range(len(s)):
    if s[i].count('A') < 25:
        for j in range(len(s[i])):
            for k in range(len(s[i])-1, j, -1):
                if s[i][j] == s[i][k]:
                    cnt = k - j
                    lens.append(cnt)
                    cnt = 0
                    
                
max(lens)
# Out:
# 1004

# %% [markdown]
# Текстовый файл 24_9 состоит не более чем из 1 200 000 символов X, Y, и Z. Определите максимальное количество идущих подряд символов, среди которых нет подстроки XZZY. Для выполнения этого задания следует написать программу. Ниже приведён файл, который необходимо обработать с помощью данного алгоритма.

# %%
with open('24_9.txt') as f:
    s = f.readline()
lens = []
cnt = 0
i =0
while i < (len(s)-3):
    if s[i] == 'X':
        if s[i+1] == 'Z':
            if s[i+2] == 'Z':
                if s[i+3] == 'Y':
                    cnt += 3
                    lens.append(cnt)
                    cnt = 0
                    i +=1
                else:
                    cnt +=1
                    i +=1
            else:
                cnt +=1
                i +=1
        else:
            i +=1
            cnt +=1
    else:
        i +=1
        cnt +=1

max(lens)
# Out:
# 1713

# %%
with open('24_10.txt') as f:
    l = f.readline()
cnt = 0
n = 0
l=l.replace('1', 'a').replace('2', 'a').replace('4', 'a')
l=l.replace('Q', 'b').replace('R', 'b').replace('W', 'b')
for i in range(len(l)-1):
    if l[i] + l[i+1] != 'aa' and l[i] + l[i+1] != 'bb':
        cnt +=1
        n = max(cnt, n)
    else:
        cnt = 1
n
# Out:
# 17

# %%
with open('24_11.txt') as f:
    l = f.readline()

cnt = 1
n = 0
t = 0
for i in range(len(l)-1):
    if (l[i] + l[i+1] != 'DE'):
        cnt += 1
        n = max(n, cnt)
    elif t <= 240:
        t += 1
        cnt += 1
        n = max(n, cnt)
    else:
        n = max(n, cnt +1)
        cnt = 1
n
# Out:
# 970249

# %%
with open('24_12.txt') as f:
    s = f.readline()

cnt = 0
n = 0
for i in range(len(l)-1):
    if (s[i] in '6780') or (s[i-1] in '678' and s[i+1] in '678' and cnt != 0):
        cnt +=1
    else:
        n = max(n, cnt)
        cnt = 0
n
# Out:
# 40

# %%
with open('24_13.txt') as f:
    s = f.readline()

cnt = 0
n = 0
fl = 1
for i in range(len(s)-1):
    fl = 1
    if s[i] == 'A':
        cnt += 1
    if (s[i] in '123456') and s[i-1] == "A":
        for j in range(i+1, len(s) - 1):
            if ( s[j]  in '123456' or (s[j] in '-*' and s[j+1] in '123456'))==0:
                fl = 0
                break
    if fl:
        n = max(n, cnt)
        cnt = 0
    else:
        cnt = 0
n
# Out:
# 1

# %%
with open('24_14.txt') as f:
    s = f.readline()

cnt = 0
n = 0
ch = '2468AC'
m = '0123456789ABCD'
fl = 0

for i in range(len(s)):

    if s[i] in m:
        if fl:
            cnt += 1
        else:
            if s[i] != '0':
                fl = 1
                cnt +=1
    else:
        cnt = 0
        fl = 0

    if s[i] in ch:
        n = max(cnt, n)

n
# Out:
# 2598

# %%
with open('24_15.txt') as f:
    s = f.readline()

cnt = 0
n = 0
cnty = 0
cnt2 = 0
i = 0
while i < (len(l)-3):
    if s[i] + s[i+1] + s[i+2] + s[i+3] == '2025':
        cnt += 4
        j = i + 4
        while j <  (i+4, len(s)-3):
            if s[j] == 'Y':
                cnty += 1
                cnt += 1
                j += 1
            if s[j] + s[j+1] + s[j+2] + s[j+3] == '2025':
                cnt += 4
                cnt2 +=1
                j += 4
            if cnt2 == 60 and cnty >= 120:
                n = max(n, cnt)
                i += cnt
                cnt  = 0
                cnt2 = 0
                cnty = 0
                break
            j += 1
        i += 1
        cnt  = 0
        cnt2 = 0
        cnty = 0
    
n
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 10
#       8 i = 0
#       9 while i < (len(l)-3):
# ---> 10     if s[i] + s[i+1] + s[i+2] + s[i+3] == '2025':
#      11         cnt += 4
#      12         j = i + 4
#
# KeyboardInterrupt:

# %% [markdown]
# Текстовый файл состоит из десятичных цифр и заглавных букв латинского алфавита. Определите в прилагаемом файле максимальное количество идущих подряд символов, среди которых подстрока K9 встречается не более 150 раз, при этом искомая последовательность не оканчивается символом D.
#
# В ответе запишите число — количество символов в найденной последовательности.
#
# Для выполнения этого задания следует написать программу.

# %%
with open('24_16.txt') as f:
    s = f.readline()
a=[]
cnt = 0
i =0
c = 0
while i < (len(s)-1):
    c += 1
    if s[i] == "K":
        if s[i+1] == '9':
            cnt += 1
            i += 2
        else:
            i += 1
    else:
        i += 1
    if cnt == 150:
        j = i+1
        while j < len(s)-1:
            if s[j] != "D":
                c += 1
                j += 1
            else:
                break
        a.append(c)
        c = 0
        cnt = 0
max(a)
# Out:
# 237161

# %%
with open('24_17.txt') as f:
    s = f.readline().strip()

d = {r: 0 for r in 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'}

for i in range(len(s) - 2):
    if s[i] == s[i + 2]:
        d[s[i + 1]] += 1

print(max(d, key=d.get))
# Out:
# D

# %%
with open('24_18.txt') as f:
    s = f.readlines()
d = dict()

for r in 'QWERTYUIOPASDFGHJKLZXCVBNM':
    d[r] = 0
ss = ''
cnt = 99999999
for i in range(len(s)-1, 0, -1):
    s[i]=s[i].strip()
    if s[i].count('G') <= cnt:
        cnt = s[i].count('G')
        ss = s[i]
for j in range(len(ss)):
    d[ss[j]] += 1

d
# Out:
# {'Q': 38,
#  'W': 28,
#  'E': 27,
#  'R': 39,
#  'T': 50,
#  'Y': 40,
#  'U': 39,
#  'I': 48,
#  'O': 27,
#  'P': 38,
#  'A': 44,
#  'S': 36,
#  'D': 50,
#  'F': 44,
#  'G': 18,
#  'H': 34,
#  'J': 44,
#  'K': 40,
#  'L': 37,
#  'Z': 39,
#  'X': 46,
#  'C': 36,
#  'V': 25,
#  'B': 30,
#  'N': 42,
#  'M': 43}

# %%
with open('24_19.txt') as f:
    s = f.read().strip()

max_len = 0
count_e = 0
current_len = 0

for c in s:
    if c == 'A':
        current_len = 0
        count_e = 0
    else:
        current_len += 1
        if c == 'E':
            count_e += 1
        if count_e >= 3:
            max_len = max(max_len, current_len)

print(max_len)
# Out:
# 282

# %%
f = open('24_20.txt', 'r')
s = f.readline().strip()
start = s.find('E')
finish = s.find('E', start+1)

l = []

while finish != -1:
    if finish - start + 1 > 11 and s[start:finish+1].count('F') == 0:
        l.append(finish-start+1)
    start = finish
    finish = s.find('E', start+1)

print(len(l))
# Out:
# 9655

# %%
with open('24_21.txt') as f:
    s = f.read().strip()

vowels = {'A', 'O'}
consonants = {'C', 'D', 'F'}

max_pairs = 0
current_pairs = 0
i = 0

while i < len(s) - 1:
    if s[i] in consonants and s[i+1] in vowels:
        current_pairs += 1
        i += 2
    else:
        current_pairs = 0
        i += 1
    max_pairs = max(max_pairs, current_pairs)

print(max_pairs)
# Out:
# 95

# %%
with open('24_22.txt') as f:
    s = f.read().strip()

max_len = 0
i = 0
while i < len(s):
    if s[i] == 'F':
        count_a = 0
        length = 1
        j = i + 1
        while j < len(s):
            if s[j] == 'F':
                length += 1
                break
            if s[j] == 'A':
                count_a += 1
                if count_a > 2:
                    break
            length += 1
            j += 1
        if j < len(s) and s[j] == 'F':
            max_len = max(max_len, length)
        i = j
    else:
        i += 1

print(max_len)
# Out:
# 35

# %%
s = open('24_23.txt').readline()[:-2]
cifr = '0123456789'
mini = 10**10
pos = []
i = 0
while i < len(s):
    if s[i] not in cifr and s[i-1] in cifr:
        pos.append(i - 1)
        while s[i] not in cifr:
            i += 1
        if len(pos) >= 10000:
            mini = min(mini, i - pos[-10000] + 1)
    i += 1
print(mini)
# Out:
# 68616
