# %%
from math import *
d = [0]*300
for i in range(1, 101):
    d[i] = pi ** i

for i in range(101, 299, 2):
    d[i] = 2 * d[i-2]

for i in range(102, 299, 2):
    d[i] = d[i-1] + i **2

d[298] - 2 * d[295]
# Out:
# 0.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
g = [0]* 15600

for n in range(1, 15600):
    if n < 10:
        g[n] = 2 * n
    else:
        g[n] = g[n-2] + 1

print(2 * g[15548-3] + 8)
# Out:
# 15580

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import sys
sys.setrecursionlimit(10**6)
sys.set_int_max_str_digits(10**6)
def f(n):
    if n ==1:
        return 1
    if n > 1:
        return 2 * n * f(n-1)

print((f(2024)-4*f(2023))/f(2022))
# Out:
# 16362024.0

# %%
import functiontools
@lru_chache()
def f(n):
    if n ==0:
        return 0
    return f(n//10) + (n% 10)

cnt =0 
for i in range(237567892, 1134567009):
    if f(i)>f(i+1):
        cnt +=1

cnt
