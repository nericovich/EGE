# %%
from math import *
d = [0]*300
for i in range(1, 101):
    d[i] = pi ** i

for i in range(101, 299, 2):
    d[i] = 2 * d[i-2]

for i in range(102, 299, 2):
    d[i] = d[i-1] + i **2

d[298] - 2 * d[295]
# Out:
# 0.0

# %%
o = []
for i in range (100):
    for j in range (100):
        if 2 * i + 3 * j == 70:
            o.append(3**i * 2**j)
print(min(o))
# Out:
# 37748736

# %%
g = [0]* 43001

for i in range(8):
    g[i] = i

for i in range(8, 43000-2):
    g[i] =g[i-1]+4

print(g[43000-3]*3)
# Out:
# 515901

# %%
from itertools import product
count = 0
for i in product('013579', repeat=8):
    if i[0] != '0':
        if i[0] =='1' or i[0] =='3' or i[0] =='5':
            count += 1
print(count)
# Out:
# 839808

# %%
f = [0]* 8000000
for i in range(4000):
    f[i] = i

for i in range(4000, 800000):
    if i % 7 ==0:
        f[i] = i+f[i//7]
    else:
        f[i] = 567 + f[i-3]
    if f[i] > 80000:
        print(i)
        break
# Out:
# 62962

# %%
print(len(range(237567892, 1134567009, 10)))
# Out:
# 89699912
