# %%
def f(n):
    if n<3:
        return 2 * n*n+2
    else:
        if n %5==0:
            return 2 * f(n-2) + f(n//2) + n
        else:
            return 2 * n*n+f(n-2) + 1 + f(n//3)

f(100)
# Out:
# 12672818

# %%
def f(n):
    if n>15:
        return n * n + n * 2
    else:
        return f(n+2) + 2 * f(n+1)
cnt = 0
for i in range(1, 1001):
    if f(i) % 4 ==0:
        cnt +=1

cnt
# Out:
# 496

# %%
def f(n):
    if n <3:
        return 2 *n*n+2
    else:
        if n % 5 ==0:
            return 2 * f(n-2) + f(n/2) + n
        else:
            return n*n + f(n-2) + 1+f(n/3)

cnt = 0
for i in range(1, 301):
    if f(i) > 10**5:
        cnt +=1
cnt
# Out:
# 249

# %%
from functools import lru_cache
@lru_cache(None)
def f(n):
    if n >10:
        return 2 **n +3
    else:
        return f(n+2) + 2*f(n+1)

cnt =0
for i in range(-1000, 1001):
    if f(i) % 3 == 0:
        cnt += 1

cnt
# Out:
# 253

# %%
cnt = 0
for i in range(555555555, 1555555556):
    if i % 3 != 0:
        cnt +=1
    
cnt
# Out:
# 666666667

# %%
import sys
sys.setrecursionlimit(10**6)
def f(n):
    return 2 * (g(n-3) + 8)

def g(n):
    if n < 10:
        return 2*n
    else:
        return g(n-2) + 1

f(15548)
# Out:
# 15588

# %%
def f(n):
    return g(n-4) + 2

def g(n):
    if n <5:
        return n
    else:
        return g(n-1) + n + 7

f(10909)
# Out:
# 59541268

# %%
from sys import setrecursionlimit
setrecursionlimit(10**7)

def f(n):
    if n >= 19:
        return f(n - 4) + 3580
    else:
        return 6 * (g(n - 7) - 36)
    
def g(n):
    if n >= 248045:
        return n / 20 + 28
    else:
        return g(n + 9) - 4
    
print(f(673))
# Out:
# 47.0

# %%
def f(n):
    if n < 3:
        return 1
    else:
        if n % 2 == 0:
            return f(n-1) +n-1
        else:
            return f(n-2) + 2 * n - 2
        
print(f(3048)- f(3045))
# Out:
# 9139

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(n):
    if n > 3000:
        return n
    else:
        return f(n+2) +2
    
print(f(40) - f(44))
f(40)
# Out:
# 4
# 5964
