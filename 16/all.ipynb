# %%
from math import *
d = [0]*300
for i in range(1, 101):
    d[i] = pi ** i

for i in range(101, 299, 2):
    d[i] = 2 * d[i-2]

for i in range(102, 299, 2):
    d[i] = d[i-1] + i **2

d[298] - 2 * d[295]
# Out:
# 0.0

# %%
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[6], line 11
#       8     else:
#       9         return g(n-2) +n
# ---> 11 f(150774)
#
# Cell In[6], line 2, in f(n)
#       1 def f(n):
# ----> 2     return g(n-1) - g(n-5)
#
# Cell In[6], line 9, in g(n)
#       7     return 2 * (n + 1)
#       8 else:
# ----> 9     return g(n-2) +n
#
# Cell In[6], line 9, in g(n)
#       7     return 2 * (n + 1)
#       8 else:
# ----> 9     return g(n-2) +n
#
#     [... skipping similar frames: g at line 9 (2967 times)]
#
# Cell In[6], line 9, in g(n)
#       7     return 2 * (n + 1)
#       8 else:
# ----> 9     return g(n-2) +n
#
# Cell In[6], line 6, in g(n)
#       5 def g(n):
# ----> 6     if n <= 25:
#       7         return 2 * (n + 1)
#       8     else:
#
# RecursionError: maximum recursion depth exceeded in comparison
