# %%
from itertools import *
cnt =0 
for i in product('весна', repeat=5):
    s=''.join(i)
    if s[0] == 'н':
        if s.count('в')== 2:
            if s.count('е') <= 1 and s.count('с') <= 1 and s.count('н') <= 1 and s.count('а') <= 1:
                cnt +=1 

cnt
# Out:
# 36

# %%
s = '0123456789awe'
cnt =0
for i in product(s, repeat=6):
    t= ''.join(i)
    if t[0] != '0':
        if t.count('5') <= 1:
            t = t.replace('1','q').replace('3','q').replace('5','q').replace('7','q').replace('9','q').replace('w','q')
            if not 'qq' in t:
                cnt +=1

cnt
# Out:
# 1666784

# %%
cnt = 0
for i in product('блогер', repeat=4):
    s=''.join(i)
    if s.count('г') == 1:
        s = s.replace('о', 'q').replace('е', 'q')
        if not 'qq' in s:
            cnt +=1 

cnt
# Out:
# 396

# %%
from itertools import *

cnt = 0
ans = 0
for i in product('веностчь', repeat=6):
    s = ''.join(i)
    cnt +=1
    if s.count('о') >=2:
        if s[0]  in 'еоь':
            if cnt % 2 ==0:
                ans += 1
ans
# Out:
# 14509

# %%
from itertools import *

t = '0123456'
cnt = 0
for i in product(t, repeat=6):
    s = ''.join(i)
    if s[0] in '246':
        if s.count('5') == 2:
            cnt +=1

cnt
# Out:
# 6480

# %%
from itertools import *
cnt =0
for i in product('адлосфцщ', repeat=4):
    s=''.join(i)
    cnt +=1
    if cnt % 2 ==1:
        if s[0] != 'а' and s[-1] != 'а':
            if s.count('л')>=3:
                print(s, cnt)
                break
# Out:
# дллл 659

# %%
from itertools import *
cnt = 0
for i in product('агинрт', repeat=6):
    s = ''.join(i)
    cnt +=1
    if cnt % 2 == 1:
        if s[0] not in 'аиг' and s.count('а')== 1:
            print(s, cnt)
            break
# Out:
# наггги 23589

# %%
cnt = 0
for x1 in '123456':
    for x2 in '0123456':
        for x3 in '0123456':
            for x4 in '0123456':
                for x5 in '0123456':
                        s = x1+x2+x3+x4+x5
                        if s.count('0') == 1 and s.count('1')<= 2:
                            cnt +=1
cnt
# Out:
# 5100

# %%
from itertools import *
cnt = 0
for i in product('гекло', repeat=6):
    s = ''.join(i)
    cnt +=1
    if s.count('г')>=2:
        if 'гг' not in s:
            print(cnt, s)
# Out:
# 652 гегеге
# 653 гегегк
# 654 гегегл
# 655 гегего
# 656 гегеег
# 657 гегеее
# 658 гегеек
# 659 гегеел
# 660 гегеео
# 661 гегекг
# 662 гегеке
# 663 гегекк
# 664 гегекл
# 665 гегеко
# 666 гегелг
# 667 гегеле
# 668 гегелк
# 669 гегелл
# 670 гегело
# 671 гегеог
# 672 гегеое
# 673 гегеок
# 674 гегеол
# 675 гегеоо
# 677 гегкге
# 678 гегкгк
# 679 гегкгл
# 680 гегкго
# 681 гегкег
# 682 гегкее
# 683 гегкек
# 684 гегкел
# 685 гегкео
# 686 гегккг
# 687 гегкке
# 688 гегккк
# 689 гегккл
# 690 гегкко
# 691 гегклг
# 692 гегкле
# 693 гегклк
# 694 гегклл
# 695 гегкло
# 696 гегког
# 697 гегкое
# 698 гегкок
# 699 гегкол
# 700 гегкоо
# 702 геглге
# 703 геглгк
# 704 геглгл
# 705 геглго
# 706 геглег
# 707 геглее
# 708 геглек
# 709 геглел
# 710 геглео
# 711 геглкг
# 712 геглке
# 713 геглкк
# 714 геглкл
# 715 геглко
# 716 гегллг
# 717 геглле
# 718 гегллк
# 719 гегллл
# 720 геглло
# 721 геглог
# 722 геглое
# 723 геглок
# 724 геглол
# 725 геглоо
# 727 гегоге
# 728 гегогк
# 729 гегогл
# 730 гегого
# ...

# %%
from itertools import *
cnt = 0
for i in product('бандероль', repeat=7):
    s=''.join(i)
    if s.count('ь') <=1:
        for j in 'бндрл':
            s=s.replace(j,'q')
        if not 'qе' in s or not 'еq' in s:
            cnt +=1

cnt
# Out:
# 3027810
