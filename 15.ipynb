# %%
for A in range(5000, 0, -1):
    if all((x % A == 0) or (x % 48 != 0) or (x % 35 != 0)
           for x in range(1, 5000)):
        print(A)
        break
# Out:
# 1680

# %%
for a in range(100000, 1, -1):
    fl = 1
    for x in range(10000):
        for y in range(10000):
            if ((y > a) or ((2*y + 3 * x) != 152) or (a < x)) == 0:
                fl = 0
                break
        if fl == 0:
            break
    if fl:
        print(a)
        break
# Out:
# 30

# %%
for a in range(19532, 10000000000):
    fl = 1
    for x in range(17031, 100000):
        for y in range(10000):
            if ((78125 != (y+4*x)) or ((a > x) and (a>y))) == 0:
                fl = 0
                break
        if fl == 0:
            break
    if fl:
        print(a)
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       3 for x in range(17031, 100000):
#       4     for y in range(10000):
# ----> 5         if ((78125 != (y+4*x)) or ((a > x) and (a>y))) == 0:
#       6             fl = 0
#       7             break
#
# KeyboardInterrupt:

# %%
def f(a, b):
    if a % b ==0:
        return 1
    else:
        return 0

for a in range(100000, 1, -1):
    fl = 1
    for x in range(1000):
        if ((not (f(x, 21))) or f(x, a) or (not (f(x, 77)))) == 0:
            fl = 0
            break
    if fl:
        print(a)
        break
# Out:
# 231

# %%
2022*2023
# Out:
# 4090506

# %%
def f(a, b):
    if a % b ==0:
        return 1
    else:
        return 0
    
for a in range(1, 10000000000):
    fl = 1
    for x in range(1, 100000):
        if (not(f(x,3) and f(x, 5)) or (a>=42-x)) == 0:
            fl = 0
            break
    if fl:
        print(a)
        break
# Out:
# 27
