# %%
from math import fabs


def f(S):
    petya = (S - 1) + S
    if petya >= 100:
        return False  


    vanya = petya + (S - 2)
    if vanya >= 100:
        return False

    p2 = vanya + (S - 3)
    if p2 >= 100:
        return False  
    v2 = p2 + (S - 4)
    if v2 >= 100:
        return True
    return False

def f1(S):
    petya = (S - 1) + S
    if petya >= 100:
        return False  


    vanya = petya + (S - 2)
    if vanya >= 100:
        return True
    return False

for S in range(14, 100):
    if f(S) and not f1(S):
        print(S)
# Out:
# 22
# 23
# 24
# 25
# 26

# %%
def d(x, y):
    return (x **2 + y ** 2) ** 0.5

def f(x, y, p):
    if d(x, y)  > 14 and (p == 4 or p == 2): 
        return True
    if d(x, y)  > 14 and p < 4:
        return False
    if d(x, y)  <= 14 and p == 4:
        return False
    
    h = [f(2*x,y,p+1), f(x, y+3, p+1), f(x, y+4, p+1)]

    if p % 2 == 1:
        return any(h)
    else:
        return all(h)


def f1(x, y, p):
    if d(x, y)  > 14 and p == 2: 
        return True
    if d(x, y)  > 14 and p < 2:
        return False
    if d(x, y)  <= 14 and p == 2:
        return False
    
    h = [f1(2*x,y,p+1), f1(x, y+3, p+1), f1(x, y+4, p+1)]

    if p % 2 == 1:
        return any(h)
    else:
        return all(h)
    


for s in range(1, 14):
    if f(3, s, 0) and not f1(3, s, 0):
        print(s)
# Out:
# 1
# 2
# 3

# %%
def d(x, y):
    return (x **2 + y ** 2) ** 0.5

def f(x, y, p):
    if d(x, y)  > 14 and p == 3: 
        return True
    if d(x, y)  > 14 and p < 3:
        return False
    if d(x, y)  <= 14 and p == 3:
        return False
    
    h = [f(2*x,y,p+1), f(x, y+3, p+1), f(x, y+4, p+1)]

    if p % 2 == 0:
        return any(h)
    else:
        return all(h)
    
for s in range(1, 14):
    if f(3, s, 0):
        print(s)
# Out:
# 4
# 5
# 6
# 7

# %%
def f1(x, p):
    if x >= 349 and (p ==3 or p ==5):
        return 1
    if x >= 349 and p < 5:
        return 0
    if x <349 and p ==5:
        return 0
    
    h = [f1(x+2, p+1), f1(x+3, p+1), f1(x*3, p +1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)

for s in range(1, 349):
    if f(s, 1):
        print(s)
        break
# Out:
# 115

# %%
def f(x, p):
    if x >= 349 and p ==3:
        return 1
    if x >= 349 and p < 3:
        return 0
    if x <349 and p ==3:
        return 0
    
    h = [f(x+2, p+1), f(x+3, p+1), f(x*3, p +1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)

for s in range(1, 349):
    if f1(s, 1) and not f(s, 1):
        print(s)
# Out:
# 110
# 111

# %%
def f(x, y, p):
    if x + y <= 150 and (p == 3 or p ==5):
        return 1
    if x + y >150 and p == 5:
        return 0 
    if x + y <= 150 and p < 5:
        return 0
    
    h = [f(x-2, y, p+1), f(x//3, y, p+1), f(x, y-2, p+1), f(x, y //3, p+1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)
    
def f1(x, y, p):
    if x + y <= 150 and p == 3:
        return 1
    if x + y >150 and p == 3:
        return 0 
    if x + y <= 150 and p < 3:
        return 0
    
    h = [f1(x-2, y, p+1), f1(x//3, y, p+1), f1(x, y-2, p+1), f1(x, y //3, p+1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)
    
for s in range(135, 1000):
    if f(17, s, 1) and not f1(17, s, 1):
        print(s)
# Out:
# 406
# 407
# 410
# 411

# %%
def f1(x, p):
    if x >= 125 and p == 3:
        return 1
    if x >= 125 and p < 3:
        return 0
    if x <125 and p == 3:
        return 0
    h = [f1(x+2, p+1), f1(x+4, p+1), f1(x*2, p+1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)
    

def f(x, p):
    if x >= 125 and (p == 3 or p == 5):
        return 1
    if x >= 125 and p < 5:
        return 0
    if x <125 and p == 5:
        return 0
    h = [f(x+2, p+1), f(x+4, p+1), f(x*2, p+1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)
    
for s in range(1, 125):
    if f(s, 1) and not f1(s, 1):
        print(s)
# Out:
# 55
# 56

# %%
def f(x, p):
    if x >= 125 and p == 4:
        return 1
    if x >= 125 and p < 4:
        return 0
    if x <125 and p == 4:
        return 0
    h = [f(x+2, p+1), f(x+4, p+1), f(x*2, p+1)]
    if p % 2 == 1:
        return any(h)
    else:
        return all(h)
    
for s in range(1, 125):
    if f(s, 1):
        print(s)
# Out:
# 31
# 57
# 58
# 59
# 60

# %%
def f(x, y, p):
    if (x +  y)  >= 207 and p == 3: 
        return True
    if (x +  y)  >= 207 and p < 3:
        return False
    if (x + y)  < 207 and p == 3:
        return False
    
    h = [f(2*x,y,p+1), f(x, y*2, p+1), f(x, y+1, p+1) + f(x+1, y, p+1)]

    return any(h)
    
for s in range(1, 189):
    if f(17, s, 1):
        print(s)
        break
# Out:
# 48

# %%
def f(x, y, p):
    if (x +  y)  >= 207 and p == 4: 
        return True
    if (x +  y)  >= 207 and p < 4:
        return False
    if (x + y)  < 207 and p == 4:
        return False
    
    h = [f(2*x,y,p+1), f(x, y*2, p+1), f(x, y+1, p+1) + f(x+1, y, p+1)]
    if p % 2 == 1:
        return any(h)
    else:
        return all(h)
    
for s in range(1, 189):
    if f(17, s, 1):
        print(s)
# Out:
# 47
# 86
# 93
# 94

# %%
def f1(x, y, p):
    if (x +  y)  >= 207 and p == 3: 
        return True
    if (x +  y)  >= 207 and p < 3:
        return False
    if (x + y)  < 207 and p == 3:
        return False
    
    h = [f1(2*x,y,p+1), f1(x, y*2, p+1), f1(x, y+1, p+1) + f1(x+1, y, p+1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)
    
def f(x, y, p):
    if (x +  y)  >= 207 and (p == 3 or p ==5): 
        return True
    if (x +  y)  >= 207 and p < 5:
        return False
    if (x + y)  < 207 and p == 5:
        return False
    
    h = [f(2*x,y,p+1), f(x, y*2, p+1), f(x, y+1, p+1) + f(x+1, y, p+1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)
    
for s in range(1, 189):
    if f(17, s, 1) and not f1(17, s, 1):
        print(s)
# Out:
# 85
# 92
# 93

# %%
from sys import setrecursionlimit
setrecursionlimit(10**7)

def f(x, p):
    # победа: попали в диапазон
    if 55 <= x <= 77:
        return p == 3  # Ваня сделал ход

    # перебор (перелёт — проигрыш текущего игрока)
    if x > 77:
        return 0

    h = [f(x+3, p+1), f(x*2, p+1), f(x*3, p+1)]

    if p % 2 == 0:   # ход Вани
        return any(h)
    else:            # ход Пети
        return all(h)


def f1(x, p):
    # победа: Ваня мог выиграть на 1 или 2 своём ходе
    if 55 <= x <= 77:
        return p == 3 or p == 5

    if x > 77:
        return 0

    h = [f1(x+3, p+1), f1(x*2, p+1), f1(x*3, p+1)]

    if p % 2 == 0:
        return any(h)
    else:
        return all(h)


for s in range(1, 55):
    if f1(s, 1) and not f(s, 1):
        print(s)
# Out:
# 3
# 12
