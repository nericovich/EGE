# %%
from math import fabs


def f(S):
    petya = (S - 1) + S
    if petya >= 100:
        return False  


    vanya = petya + (S - 2)
    if vanya >= 100:
        return False

    p2 = vanya + (S - 3)
    if p2 >= 100:
        return False  
    v2 = p2 + (S - 4)
    if v2 >= 100:
        return True
    return False

def f1(S):
    petya = (S - 1) + S
    if petya >= 100:
        return False  


    vanya = petya + (S - 2)
    if vanya >= 100:
        return True
    return False


for S in range(14, 100):
    if f(S) and not f1(S):
        print(S)
# Out:
# 22
# 23
# 24
# 25
# 26

# %%
def d(x, y):
    return (x **2 + y ** 2) ** 0.5

def f(x, y, p):
    if d(x, y)  > 14 and (p == 4 or p == 2): 
        return True
    if d(x, y)  > 14 and p < 4:
        return False
    if d(x, y)  <= 14 and p == 4:
        return False
    
    h = [f(2*x,y,p+1), f(x, y+3, p+1), f(x, y+4, p+1)]

    if p % 2 == 1:
        return any(h)
    else:
        return all(h)


def f1(x, y, p):
    if d(x, y)  > 14 and p == 2: 
        return True
    if d(x, y)  > 14 and p < 2:
        return False
    if d(x, y)  <= 14 and p == 2:
        return False
    
    h = [f1(2*x,y,p+1), f1(x, y+3, p+1), f1(x, y+4, p+1)]

    if p % 2 == 1:
        return any(h)
    else:
        return all(h)
    


for s in range(1, 14):
    if f(3, s, 0) and not f1(3, s, 0):
        print(s)
# Out:
# 1
# 2
# 3

# %%
def d(x, y):
    return (x **2 + y ** 2) ** 0.5

def f(x, y, p):
    if d(x, y)  > 14 and p == 3: 
        return True
    if d(x, y)  > 14 and p < 3:
        return False
    if d(x, y)  <= 14 and p == 3:
        return False
    
    h = [f(2*x,y,p+1), f(x, y+3, p+1), f(x, y+4, p+1)]

    if p % 2 == 0:
        return any(h)
    else:
        return all(h)
    
for s in range(1, 14):
    if f(3, s, 0):
        print(s)
# Out:
# 4
# 5
# 6
# 7

# %%
def f1(x, p):
    if x >= 349 and (p ==3 or p ==5):
        return 1
    if x >= 349 and p < 5:
        return 0
    if x <349 and p ==5:
        return 0
    
    h = [f1(x+2, p+1), f1(x+3, p+1), f1(x*3, p +1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)

for s in range(1, 349):
    if f(s, 1):
        print(s)
        break
# Out:
# 115

# %%
def f(x, p):
    if x >= 349 and p ==3:
        return 1
    if x >= 349 and p < 3:
        return 0
    if x <349 and p ==3:
        return 0
    
    h = [f(x+2, p+1), f(x+3, p+1), f(x*3, p +1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)

for s in range(1, 349):
    if f1(s, 1) and not f(s, 1):
        print(s)
# Out:
# 110
# 111

# %%
def f(x, y, p):
    if x + y <= 150 and (p == 3 or p ==5):
        return 1
    if x + y >150 and p == 5:
        return 0 
    if x + y <= 150 and p < 5:
        return 0
    
    h = [f(x-2, y, p+1), f(x//3, y, p+1), f(x, y-2, p+1), f(x, y //3, p+1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)
    
def f1(x, y, p):
    if x + y <= 150 and p == 3:
        return 1
    if x + y >150 and p == 3:
        return 0 
    if x + y <= 150 and p < 3:
        return 0
    
    h = [f1(x-2, y, p+1), f1(x//3, y, p+1), f1(x, y-2, p+1), f1(x, y //3, p+1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)
    
for s in range(135, 1000):
    if f(17, s, 1) and not f1(17, s, 1):
        print(s)
# Out:
# 406
# 407
# 410
# 411

# %%
def f1(x, p):
    if x >= 125 and p == 3:
        return 1
    if x >= 125 and p < 3:
        return 0
    if x <125 and p == 3:
        return 0
    h = [f1(x+2, p+1), f1(x+4, p+1), f1(x*2, p+1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)
    

def f(x, p):
    if x >= 125 and (p == 3 or p == 5):
        return 1
    if x >= 125 and p < 5:
        return 0
    if x <125 and p == 5:
        return 0
    h = [f(x+2, p+1), f(x+4, p+1), f(x*2, p+1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)
    
for s in range(1, 125):
    if f(s, 1) and not f1(s, 1):
        print(s)
# Out:
# 55
# 56

# %%
def f(x, p):
    if x >= 125 and p == 4:
        return 1
    if x >= 125 and p < 4:
        return 0
    if x <125 and p == 4:
        return 0
    h = [f(x+2, p+1), f(x+4, p+1), f(x*2, p+1)]
    if p % 2 == 1:
        return any(h)
    else:
        return all(h)
    
for s in range(1, 125):
    if f(s, 1):
        print(s)
# Out:
# 31
# 57
# 58
# 59
# 60

# %%
def f(x, y, p):
    if (x +  y)  >= 207 and p == 3: 
        return True
    if (x +  y)  >= 207 and p < 3:
        return False
    if (x + y)  < 207 and p == 3:
        return False
    
    h = [f(2*x,y,p+1), f(x, y*2, p+1), f(x, y+1, p+1) + f(x+1, y, p+1)]

    return any(h)
    
for s in range(1, 189):
    if f(17, s, 1):
        print(s)
        break
# Out:
# 48

# %%
def f(x, y, p):
    if (x +  y)  >= 207 and p == 4: 
        return True
    if (x +  y)  >= 207 and p < 4:
        return False
    if (x + y)  < 207 and p == 4:
        return False
    
    h = [f(2*x,y,p+1), f(x, y*2, p+1), f(x, y+1, p+1) + f(x+1, y, p+1)]
    if p % 2 == 1:
        return any(h)
    else:
        return all(h)
    
for s in range(1, 189):
    if f(17, s, 1):
        print(s)
# Out:
# 47
# 86
# 93
# 94

# %%
def f1(x, y, p):
    if (x +  y)  >= 207 and p == 3: 
        return True
    if (x +  y)  >= 207 and p < 3:
        return False
    if (x + y)  < 207 and p == 3:
        return False
    
    h = [f1(2*x,y,p+1), f1(x, y*2, p+1), f1(x, y+1, p+1) + f1(x+1, y, p+1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)
    
def f(x, y, p):
    if (x +  y)  >= 207 and (p == 3 or p ==5): 
        return True
    if (x +  y)  >= 207 and p < 5:
        return False
    if (x + y)  < 207 and p == 5:
        return False
    
    h = [f(2*x,y,p+1), f(x, y*2, p+1), f(x, y+1, p+1) + f(x+1, y, p+1)]
    if p % 2 == 0:
        return any(h)
    else:
        return all(h)
    
for s in range(1, 189):
    if f(17, s, 1) and not f1(17, s, 1):
        print(s)
# Out:
# 85
# 92
# 93

# %%
from sys import setrecursionlimit
setrecursionlimit(10**7)

def f(x, p):
    if 55 <= x <= 77:
        return p == 3 


    if x > 77:
        return 0

    h = [f(x+3, p+1), f(x*2, p+1), f(x*3, p+1)]

    if p % 2 == 0: 
        return any(h)
    else:    
        return all(h)


def f1(x, p):

    if 55 <= x <= 77:
        return p == 3 or p == 5

    if x > 77:
        return 0

    h = [f1(x+3, p+1), f1(x*2, p+1), f1(x*3, p+1)]

    if p % 2 == 0:
        return any(h)
    else:
        return all(h)


for s in range(1, 55):
    if f1(s, 1) and not f(s, 1):
        print(s)
# Out:
# 3
# 12

# %% [markdown]
# # ------------------------------------

# %%
def f(x, y, p):
    t = x+y
    if 60<=t<=79 and p ==3:
        return 1
    elif t>79 and p==2:
        return 0
    elif 60<=t<=79 and p ==2:
        return 0
    elif p>3:
        return 0
    h=[f(x+1, y, p+1), f(x, y+1, p+1), f(x*3, y, p+1), f(x, y*3, p+1)]
    if p%2==0:
        return any(h)
    else:
        return all(h)
    

for s in range(1, 52):
    if f(8, s, 1):
        print(s)
# Out:
# 17

# %% [markdown]
# #
#  ------------------------------------

# %%
def f(x, y, p):
    rast = (x**2+y**2)**0.5
    if rast <12 and p ==3:
        return 1
    if rast <12 and p <3:
        return 0
    if rast >12 and p ==3:
        return 0 
    h=[f(x-3, y-1, p+1), f(x-1, y-2, p+1)]
    if p % 2==0:
        return any(h)
    return all(h)

for s in range(7, 100):
    if f(10, s, 1):
        print(s)
# Out:
# 11
# 12
# 13

# %%
def f(x, y, p):
    rast = (x**2+y**2)**0.5
    if rast <12 and p ==4:
        return 1
    if rast <12 and p <4:
        return 0
    if rast >12 and p ==4:
        return 0 
    h=[f(x-3, y-1, p+1), f(x-1, y-2, p+1)]
    if p % 2==1:
        return any(h)
    return all(h)

for s in range(7, 100):
    if f(10, s, 1):
        print(s)
# Out:
# 14
# 15

# %%
def f(x, y, p):
    rast = (x**2+y**2)**0.5
    if rast <12 and p ==5:
        return 1
    if rast <12 and p <5:
        return 0
    if rast >12 and p ==5:
        return 0 
    h=[f(x-3, y-1, p+1), f(x-1, y-2, p+1)]
    if p % 2==0:
        return any(h)
    return all(h)

for s in range(7, 100):
    if f(10, s, 1):
        print(s)
# Out:
# 16
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[3], line 15
#      12     return all(h)
#      14 for s in range(7, 100):
# ---> 15     if f(10, s, 1):
#      16         print(s)
#
# Cell In[3], line 9, in f(x, y, p)
#       7 if rast >12 and p ==5:
#       8     return 0
# ----> 9 h=[f(x-3, y-1, p+1), f(x-1, y-2, p+1)]
#      10 if p % 2==0:
#      11     return any(h)
#
# Cell In[3], line 9, in f(x, y, p)
#       7 if rast >12 and p ==5:
#       8     return 0
# ----> 9 h=[f(x-3, y-1, p+1), f(x-1, y-2, p+1)]
#      10 if p % 2==0:
#      11     return any(h)
#
#     [... skipping similar frames: f at line 9 (2968 times)]
#
# Cell In[3], line 9, in f(x, y, p)
#       7 if rast >12 and p ==5:
#       8     return 0
# ----> 9 h=[f(x-3, y-1, p+1), f(x-1, y-2, p+1)]
#      10 if p % 2==0:
#      11     return any(h)
#
# Cell In[3], line 3, in f(x, y, p)
# ...
