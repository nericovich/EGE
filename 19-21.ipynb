# %%
from math import fabs


def f(S):
    petya = (S - 1) + S
    if petya >= 100:
        return False  


    vanya = petya + (S - 2)
    if vanya >= 100:
        return False

    p2 = vanya + (S - 3)
    if p2 >= 100:
        return False  
    v2 = p2 + (S - 4)
    if v2 >= 100:
        return True
    return False

def f1(S):
    petya = (S - 1) + S
    if petya >= 100:
        return False  


    vanya = petya + (S - 2)
    if vanya >= 100:
        return True
    return False

for S in range(14, 100):
    if f(S) and not f1(S):
        print(S)
# Out:
# 22
# 23
# 24
# 25
# 26
