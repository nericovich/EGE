# %%
for i in range(1, 10000): 
    num = 7 * 512 **120 - 6*64**100+8*210-255
    if num % i == 1: 
        num //= i 
        if num % i == 0: 
            num //= i 
            if num % i == 0: 
                print(i)
# Out:
# 2

# %%
def f(n):
    s = ''
    while n > 0:
        s = str(n % 5) + s
        n //= 5
    return s
maxi = 0

for x in range(1, 2031):
    num = 5 ** 100 - x
    if f(num).count('0') > maxi:
        maxi = f(num).count('0')
        c = x
        print(c)
x
# Out:
# 5
# 25
# 125
# 625
# 2030

# %% [markdown]
# Операнды арифметического выражения записаны в системе счисления с основанием 23.
#
# 324
# x
# 72
# 23
# +
# 45
# x
# 562
# 23
# 324x72
# 23
# ​
#  +45x562
# 23
# ​
#
#
# В записи чисел переменной х обозначена неизвестная цифра из алфавита системы счисления с основанием 23.
#
# Определите наименьшее значение х, при котором значение данного арифметического выражения кратно 22. Для найденного х вычислите частное от деления значения арифметического выражения на 22 и укажите его в ответе в десятичной системе счисления. Основание системы счисления указывать не нужно.

# %%
num = 3 * 23 ** 5 + 2* 23 ** 4 + 4* 23 ** 3 + 7* 23 ** 1 + 2* 23 ** 0 + 4 * 23 ** 5 + 5 * 23 ** 4 + 5* 23 ** 2 + 6 * 23 ** 1 + 2 * 23 ** 0

for x in range(23):
    num = 3 * 23 ** 5 + 2* 23 ** 4 + 4* 23 ** 3 + 7* 23 ** 1 + 2* 23 ** 0 + 4 * 23 ** 5 + 5 * 23 ** 4 + 5* 23 ** 2 + 6 * 23 ** 1 + 2 * 23 ** 0
    num += (x*23**2 + x *23**3)
    if num % 22 == 0:
        print(num/22)
        break
# Out:
# 2140468.0

# %%
num = 4 * 7**24 + 6*7**13 + 5 *49**4+2*343**2+10
def f(n):
    s = ''
    while n >0:
        s = str(n%7) + s
        n //= 7
    return s

for x in range(25000000, 10000000000):
    r = f(num-x)
    if r.count('6') > r.count('0'):
        print(x)
        break
# Out:
# 29059314

# %%
def f(n):
    s = ''
    while n > 0:
        s = str(n % 27) + s
        n //= 27
    return s

num = 3 * 27 ** 9 + 2 * 27 ** 6 + 27 ** 3 
for x in range(27001):
    n = f(num-x)
    if n.count('0') == 6:
        print(x)
        break
# Out:
# 7

# %%
num= 1 * 22 ** 7 + 2 * 22 **  6 + 3 * 22 **  5 +1 * 22 ** 4+3 * 22 ** 2 + 5 * 22 ** 1+7 * 22 ** 0 + 1  * 22 ** 6 + 3 * 22 ** 4+4 * 22 ** 3+4 * 22 ** 2+5 * 22 ** 2+ 6 * 22 ** 1 +1 * 22 ** 0

for x in range(22):
    n = num + x *22**2 + x * 22 ** 5
    if n % 21 ==0:
        print(n/21)
# Out:
# 140422494.0

# %%
def f(n):
    cnt = 0
    while n>0:
        if n%28 == 0:
            cnt +=1
        n//=28
    return cnt

num = 4*28**10+3*28**6+28**3
a, b =0, 0
top = 0
for x in range(28001):
    c = num - x
    if f(c) > top:
        top = f(c)
        a, b = x, c

a, b
# Out:
# (21952, 1184788512452608)

# %%
num = 15*2401**1500-10*343**1200+40*49**1000-35*7**850-4805
cnt = 0
while num > 0:
    if num % 49 >9:
        cnt +=1
    num //= 49
print(cnt)
# Out:
# 2202
