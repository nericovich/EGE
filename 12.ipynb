# %%
bin(128)
# Out:
# '0b10000000'

# %%
int('11110000100', 2)
# Out:
# 1924

# %%
for z in range(1100):

# %%
bin(2028)
# Out:
# '0b11111101100'

# %%
int('1111110110000', 2)
# Out:
# 8112

# %%
bin(800)[2:]
# Out:
# '1100100000'

# %%
int('1000100000', 2)
# Out:
# 544

# %%
bin(67)
# Out:
# '0b1000011'

# %%
int('0111100', 2)
bin(67)
# Out:
# '0b1000011'

# %%
bin(591)
# Out:
# '0b1001001111'

# %%
int('1110110001', 2)
# Out:
# 945

# %%
bin(2025)
# Out:
# '0b11111101001'

# %%
int('101111101001', 2)
# Out:
# 3049
