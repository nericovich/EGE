# %%
with open('17_1.txt') as f:
    num = [int(x) for x in f.readlines()]
mini = 100001
for i in num:
    if (i % 25 == 0) and i < mini:
        mini = i
sums = []
cnt = 0
for i in range(len(num) -1):
    if num[i] % 2 ==0 or num[i+1] % 2 ==0:
        if (num[i] + num[i+1]) % mini==0:
            cnt +=1
            sums.append(num[i] + num[i+1])

max(sums)
# Out:
# 147275

# %%
with open('17_2.txt') as f:
    num = [int(x) for x in f.readlines()]
mini = 100001
for i in num:
    if (i % 45 == 0) and i < mini and len(str(i))==3: 
        mini = i

sums = []
cnt = 0
for i in range(len(num) - 1):
    if len(str(num[i])) == 4 or len(str(num[i+1])) == 4:
        if (num[i] + num[i+1]) % mini==0:
            cnt +=1
            sums.append(num[i] + num[i+1])

min(sums)
# Out:
# 16740

# %%
with open('17_3.txt') as f:
    num = [int(x) for x in f.readlines()]
maxi = -10000000
for i in num:
    if (abs(i) % 2026 == 0) and i > maxi: 
        maxi = i

sums = []
cnt = 0

for i in range(len(num) - 1):
    if num[i] * num[i+1] <0:
         if (num[i] + num[i+1]) <= maxi:
            cnt +=1
            sums.append(num[i] + num[i+1])

max(sums)
# Out:
# 91170

# %%
with open('17_4.txt') as f:
    num = [int(x) for x in f.readlines()]

a = []
d = sorted(num, reverse=True)[0] * sorted(num, reverse=True)[1]
for i in range(len(num) - 2):
    if num[i] <0 or num[i+1] <0 or num[i+2] <0:
        if (num[i] * num[i+1] * num[i+2]) > 0:
            if (num[i] * num[i+1] * num[i+2]) <= d:  
                a.append(num[i] + num[i+1] + num[i+2])

len(a), max(a)
# Out:
# (16, 2783)

# %%
with open('17_5.txt') as f:
    num = [int(x) for x in f.readlines()]
maxi = -9999999
for i in range(len(num)):
    if 9 < num[i] < 100:
        if num[i] > maxi:
            maxi = num[i]

cnt =0
sum = []

for i in range(len(num) - 1):
    if len(str(abs(num[i]))) == 2 or len(str(abs(num[i+1]))) == 2:
        if (num[i] + num[i+1]) <= maxi:
            cnt +=1
            sum.append(num[i] + num[i+1])
       
max(sum), cnt
# Out:
# (25, 42)

# %%
with open('17_6.txt') as f:
    num = [int(x) for x in f.readlines()]


mini = 999999999
for i in range(len(num)):
    if len(str(num[i])) == 3:
           if num[i] % 45 == 0:
                if mini > num[i]:
                    mini = num[i]
ans = 99999999
cnt = 0
for j in range(len(num) - 1):
    if len(str(num[j])) == 4 or len(str(num[j+1])) == 4:
         if (num[j]+ num[j+1]) % mini == 0:
              cnt +=1
              if (num[j]+ num[j+1]) < ans:
                   ans = (num[j]+num[j+1])
cnt, ans
# Out:
# (16, 16740)

# %%
with open('17_7.txt') as f:
    num = [int(x) for x in f.readlines()]
cnt = 0 
s = []
maxi = str(max(num))[-1]
mini = str(min(num))[-1]

for i in range(len(num) - 2):
    if ((len(str(num[i])) == 4) and (len(str(num[i+1])) == 4)) or ((len(str(num[i+1])) == 4) and (len(str(num[i+2])) == 4)) or ((len(str(num[i])) == 4) and (len(str(num[i+2])) == 4)):
        if (str(num[i])[-1] == maxi) or (str(num[i+1])[-1] == maxi) or (str(num[i+2])[-1] == maxi):
            if (str(num[i])[-1] != mini) and (str(num[i+1])[-1] != mini) and (str(num[i+2])[-1] != mini):
                cnt +=1
                s.append(num[i] + num[i+1] + num[i+2])
cnt, max(s)
# Out:
# (46, 113153)

# %%
with open('17_8.txt') as f:
    num = [int(x) for x in f.readlines()]

maxi = -9999999
for i in range(len(num)):
    if num[i] % 100 == 30:
        if num[i] > maxi:
            maxi = num[i]
cnt = 0
s = []
for i in range(len(num) - 2):
    if (len(str(abs(num[i]))) != 4) and (len(str(abs(num[i+1]))) != 4) and (len(str(abs(num[i+2]))) != 4):
        if (num[i] + num[i+1] + num[i+2]) > maxi:
            cnt +=1
            s.append(num[i] + num[i+1] + num[i+2])

cnt, max(s)
# Out:
# (1141, 285423)

# %%
with open('17_9.txt') as f:
    num = [int(x) for x in f.readlines()]

maxi = -9999999
for i in range(len(num)):
    if len(str(num[i])) == 4:
        if num[i] % 100 == 43:
            if num[i] > maxi:
                maxi = num[i]
maxi = maxi**2
sums = []
cnt = 0
for i in range(len(num) - 1):
    if len(str(abs(num[i]))) == 4 or len(str(abs(num[i+1]))) == 4:
        if (num[i] + num[i+1])**2 < maxi:
            cnt +=1
            sums.append((num[i] + num[i+1])**2)

cnt, max(sums)
# Out:
# (1218, 98843364)

# %%
with open('17_10.txt') as f:
    num = [int(x) for x in f.readlines()]
mini=-1
cnt=0
sims = []
for i in range(len(num)):
    if num[i] >0:
        if num[i] % 100 == 17:
            if 0<num[i] // 10000 <10:
                if num[i] > mini:
                    mini = num[i]

for j in range(len(num) - 2):
    a, b, c = map(abs, [num[j], num[j+1], num[j+2]])
    if a % 100 == 17 or b % 100 == 17 or c % 100 == 17:

        if (a + b + c) <=mini:
            cnt +=1
            sims.append(a + b + c)
cnt, min(sims)
# Out:
# (243, 18349)

# %%
# Читаем все числа из файла в список
with open('17_11.txt') as f:
    a = [int(x) for x in f]

# 1. Находим все трехзначные числа
three_digit_numbers = [x for x in a if 100 <= x <= 999]

# 2. Находим второй минимальный трехзначный элемент
# Сортируем список по возрастанию и берем элемент с индексом 1
sorted_three_digits = sorted(list(set(three_digit_numbers))) 

# Если под "вторым минимальным" подразумевается второй по величине уникальный:
min_2 = sorted_three_digits[1] 
# Если дубликаты тоже считаются (например, 100, 100, 120 -> второй это 100), 
# то используйте sorted(three_digit_numbers)[1]

limit = min_2 ** 2

count = 0
max_sum = -float('inf')

# 3. Перебираем пары подряд идущих элементов
for i in range(len(a) - 1):
    current_sum = a[i] + a[i+1]
    if current_sum < limit:
        count += 1
        if current_sum > max_sum:
            max_sum = current_sum

print(count, max_sum)
# Out:
# 227 17405

# %%
# Считываем числа из файла в список
with open('17_12.txt') as f:
    a = [int(x) for x in f]

# Находим минимальный элемент, кратный 23
min_23 = min(x for x in a if x % 23 == 0)

count = 0
max_sum = -10**10 # Начальное значение для поиска максимума

# Перебираем пары идущих подряд элементов
for i in range(len(a) - 1):
    el1 = a[i]
    el2 = a[i+1]
    
    # Условие: хотя бы одно число кратно min_23
    if el1 % min_23 == 0 or el2 % min_23 == 0:
        count += 1
        if el1 + el2 > max_sum:
            max_sum = el1 + el2

print(count, max_sum)
# Out:
# 113 168437
